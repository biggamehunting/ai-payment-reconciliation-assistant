# %%
# Cell 1 — Imports

from dotenv import load_dotenv
import os

from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain_qdrant import QdrantVectorStore

# Explicitly load backend/.env
load_dotenv("backend/.env")
# Out:
# True

# %%
# Cell 2 — Check configuration

GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")
QDRANT_URL = os.getenv("QDRANT_URL")
QDRANT_API_KEY = os.getenv("QDRANT_API_KEY")

print("Google API key loaded:", bool(GOOGLE_API_KEY))
print("Qdrant URL loaded:", bool(QDRANT_URL))
print("Qdrant API key loaded:", bool(QDRANT_API_KEY))
# Out:
# Google API key loaded: True
# Qdrant URL loaded: True
# Qdrant API key loaded: True

# %%
# Cell 3 — Create the embedding model

embeddings = GoogleGenerativeAIEmbeddings(
    model="models/gemini-embedding-2",
    google_api_key=GOOGLE_API_KEY
)

print("Embeddings created")
# Out:
# Embeddings created

# %%
# Cell 4 — Connect to your existing Qdrant collection

vector_store = QdrantVectorStore.from_existing_collection(
    embedding=embeddings,
    collection_name="payment_policy",
    url=QDRANT_URL,
    api_key=QDRANT_API_KEY,
)

print("Connected to Qdrant")
# Out:
# Connected to Qdrant

# %%
# Cell 5 — Test RAG retrieval directly

question = "What is WACC, and how does high leverage affect its optimization curve?"

results = vector_store.similarity_search(
    question,
    k=2
)

print("Number of chunks retrieved:", len(results))

for i, doc in enumerate(results, start=1):
    print(f"\n{'=' * 60}")
    print(f"CHUNK {i}")
    print(f"{'=' * 60}")
    print(doc.page_content)
# Out:
# Number of chunks retrieved: 2
#
# ...
# CHUNK 1
# ...
# Section 3: Capital Structure, Debt Facilities & Solvency Analysis
# TOPIC: CAPITAL ALLOCATION
# Question 9: What is the Weighted Average Cost of Capital (WACC), and how does high leverage affect its
# optimization curve?
# WACC represents the blended rate of return a corporation must pay to satisfy both equity holders and debt providers, weighted
# by their respective market shares in the firm's aggregate capital structure
#
# ...
# CHUNK 2
# ...
# . While taking on lower-cost debt lowers overall WACC
# initially due to corporate tax deductibility on interest payments, exceeding optimal debt thresholds escalates financial distress
# probabilities, causing equity beta and debt credit spreads to spike, which ultimately increases the cost of capital
